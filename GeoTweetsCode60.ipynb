# %%
# created on Dec 24, 2020
# modified on April 12, 2022
# @author:          Bo Zhao
# @email:           zhaobo@uw.edu
# @website:         https://hgis.uw.edu
# @organization:    Department of Geography, University of Washington, Seattle
# @description:     Search geo-tagged tweets within the U.S. This script is modified from https://github.com/shawn-terryah/Twitter_Geolocation

# %%
import tweepy, json, time
import pandas as pd
from google.colab import files
# Create data on to Google Drive
from google.colab import drive
# Mount your Drive to the Colab VM.
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
class StreamListener(tweepy.StreamListener):
    """tweepy.StreamListener is a class provided by tweepy used to access
    the Twitter Streaming API to collect tweets in real-time.
    """

    def __init__(self, time_limit=60, file=""):
        """class initialization"""
        self.start_time = time.time()
        self.limit = time_limit
        self.result = []
        self.f = file
        super(StreamListener, self).__init__()

    def on_data(self, data):
        """This is called when data are streamed in."""
        if (time.time() - self.start_time) < self.limit:
            datajson = json.loads(data)
            # print(datajson, "\n")
            if 'id' not in datajson.keys():
                time.sleep(10)
            else:
                id = datajson['id']
                username = datajson['user']['screen_name']
                created_at = datajson['created_at']
                text = datajson['text'].strip().replace("\n", "")

                # process the geo-tags
                if datajson['coordinates'] == None:
                    try:
                        bbox = datajson['place']['bounding_box']['coordinates'][0]
                        lng = (bbox[0][0] + bbox[2][0]) / 2.0
                        lat = (bbox[0][1] + bbox[1][1]) / 2.0
                    except:
                        lat = 0
                        lng = 0
                else:
                    lng = datajson['coordinates']['coordinates'][0]
                    lat = datajson['coordinates']['coordinates'][1]

                if lat != 0:
                    row = {
                        'id': id,
                        'username': username,
                        'created_at': created_at,
                        'lng': lng,
                        'lat': lat,
                        'text': text
                    }
                    print(row)
                    self.result.append(row)
                else:
                    pass
        else:
            df = pd.DataFrame(self.result)
            df.to_csv(self.f, index=False)
            # download the csv to your local computer
            files.download(self.f)
            print("the csv has been downloaded to your local computer. The program has been completed successfully.")
            return False

# %%
if __name__ == "__main__":
    # These are provided to you through the Twitter API after you create a account
    # register a Twitter App to get the keys and access tokens.
    output_file = '/gdrive/My Drive/geotweets.csv'

    # Apply for your own Twitter API keys at https://developer.twitter.com/en/apply-for-access
    consumer_key = "mfdkZiz6WJWqoHrB56UZGus4V"
    consumer_secret = "iXE0TVbk65NOHfN5zsZeud3FK4csuuaUEa921KfwgRRxQKzLI7"
    access_token = "1516862276715696128-5eQNbOdo55b5miQTyTLsuXr85aV6JX"
    access_token_secret = "z37UTcOuRjUz3xG9dDBVmx58n7TQ8DxfthZhkVy5k6nXV"

    myauth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    myauth.set_access_token(access_token, access_token_secret)

    # LOCATIONS are the longitude, latitude coordinate corners for a box that restricts the
    # geographic area from which you will stream tweets. The first two define the southwest
    # corner of the box and the second two define the northeast corner of the box.
    LOCATIONS = [-124.7771694, 24.520833, -66.947028, 49.384472,  # Contiguous US
                 -164.639405, 58.806859, -144.152365, 71.76871,  # Alaska
                 -160.161542, 18.776344, -154.641396, 22.878623]  # Hawaii

    stream_listener = StreamListener(time_limit=60, file=output_file)
    stream = tweepy.Stream(auth=myauth, listener=stream_listener)
    stream.filter(locations=LOCATIONS, languages=['en'], encoding="utf-8")
# Out:
# {'id': 1517185313793355776, 'username': 'naijacat', 'created_at': 'Thu Apr 21 16:55:41 +0000 2022', 'lng': -73.9487755, 'lat': 40.655138, 'text': 'i just feel more creative now which is a sign'}
# {'id': 1517185315139727367, 'username': 'GumboGoon', 'created_at': 'Thu Apr 21 16:55:41 +0000 2022', 'lng': -95.12714249999999, 'lat': 29.52619, 'text': 'SHIT'}
# {'id': 1517185315034714116, 'username': 'footiusmaximus', 'created_at': 'Thu Apr 21 16:55:41 +0000 2022', 'lng': -104.92209349999999, 'lat': 39.713563, 'text': '@berman1125 Chinatown for grub and a foot massage'}
# {'id': 1517185315978596354, 'username': 'JerimilGerman', 'created_at': 'Thu Apr 21 16:55:41 +0000 2022', 'lng': -80.0883595, 'lat': 34.362393, 'text': 'A coach who believes in you and sees your worth is more than anything an athlete can ask for.'}
# {'id': 1517185316200849408, 'username': 'CallMeKaschak', 'created_at': 'Thu Apr 21 16:55:41 +0000 2022', 'lng': -97.754724, 'lat': 30.323345500000002, 'text': 'When Pluto come back into orbit?'}
# {'id': 1517185317035458560, 'username': 'StevenN26295617', 'created_at': 'Thu Apr 21 16:55:42 +0000 2022', 'lng': -75.117998, 'lat': 40.0048655, 'text': 'Mr Wallace did the right thing  - he left a network where  he worked for many years because he  finally realized  -… https://t.co/qFjuZA9W8h'}
# {'id': 1517185319233212422, 'username': 'aftncanada', 'created_at': 'Thu Apr 21 16:55:42 +0000 2022', 'lng': -123.123581, 'lat': 49.257639, 'text': "@sjblair06 Definitely. I'd hope to see us go that way. Not sure it will happen"}
# {'id': 1517185319400984587, 'username': 'Danny8bit', 'created_at': 'Thu Apr 21 16:55:42 +0000 2022', 'lng': -122.149768, 'lat': 47.5978565, 'text': '@Cybershell we’re in a Cybershell boom right now'}
# {'id': 1517185319484985344, 'username': 'midwesternexile', 'created_at': 'Thu Apr 21 16:55:42 +0000 2022', 'lng': -83.804475, 'lat': 27.698681999999998, 'text': '@GenmunJake More like this troop...'}
# {'id': 1517185319468244996, 'username': 'TeeDash1', 'created_at': 'Thu Apr 21 16:55:42 +0000 2022', 'lng': -82.44269399999999, 'lat': 27.9965945, 'text': '@therandom58 Skilled asf🔥🔥Bron beat the same Celtics team by himself https://t.co/TnvZRhsR5A'}
# {'id': 1517185320856563718, 'username': 'sugamama316', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -80.8467855, 'lat': 35.209058999999996, 'text': '@burrell_geo @js3kbullies Right!! Kobe used to open all the sugar  packs when we’d go to a restaurant 🤦🏻\u200d♀️🤦🏻\u200d♀️😂😂😂… https://t.co/EcQ46EgrWv'}
# {'id': 1517185322106470407, 'username': 'TRUlydgaf', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -89.6709275, 'lat': 35.5636175, 'text': 'weed don’t excite me no more'}
# {'id': 1517185322181808138, 'username': '____PMB', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -122.2405945, 'lat': 47.853083, 'text': 'It does 🥂'}
# {'id': 1517185322756583425, 'username': 'TotalTrafficELP', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -106.4858, 'lat': 31.75827, 'text': 'FIRE in #ElPaso on Stanton St at E San Antonio Ave #traffic https://t.co/nZ2qPHc0XJ'}
# {'id': 1517185322739806211, 'username': 'TotalTrafficABQ', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -106.6318, 'lat': 35.10501, 'text': 'Accident. Two right lanes blocked. in #Bernalillo on I-40 EB at I-25/Big I #traffic https://t.co/roJyGryxFq'}
# {'id': 1517185322618081282, 'username': 'TotalTrafficSAT', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -97.98843, 'lat': 29.82507, 'text': 'Accident reported in #Hays on I-35 (Northeast Side) NB at Center Pt Rd/Exit 200, stop and go traffic back to Watson… https://t.co/n79mIT8Gva'}
# {'id': 1517185322760740864, 'username': 'TotalTrafficLA', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -118.2304, 'lat': 33.92853, 'text': 'Accident. Right lane blocked in #Willowbrook on 105 (I-105 Century Fwy) EB at Wilmington Ave, stopped traffic back… https://t.co/zKprECLhg0'}
# {'id': 1517185322982920202, 'username': 'maxptri', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -70.71887525, 'lat': 41.78659379, 'text': 'Feeling that warm sunshine ☀️☀️ @ A D Makepeace https://t.co/w98LbzBBjy'}
# {'id': 1517185322894954496, 'username': 'TotalTrafficTUC', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -110.8837, 'lat': 32.2218, 'text': 'Accident cleared in #Tucson on Broadway Blvd at Rosemont Blvd #traffic https://t.co/bc4TAizExm'}
# {'id': 1517185323867918339, 'username': 'TotalTrafficNYC', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -73.81224, 'lat': 40.91486, 'text': 'Accident in #MtVernon on Hutchinson Riv Pky NB at E Lincoln Ave/X6A (old x12) #traffic https://t.co/cLJ9IKJQWV'}
# {'id': 1517185323872235531, 'username': 'YaBoyJersey', 'created_at': 'Thu Apr 21 16:55:43 +0000 2022', 'lng': -88.05006449999999, 'lat': 42.185631, 'text': 'That’s what the fuck he gets'}
# {'id': 1517185324765650945, 'username': 'chordaetendin_8', 'created_at': 'Thu Apr 21 16:55:44 +0000 2022', 'lng': -98.5406515, 'lat': 29.417501, 'text': '@MrChiTown76 @mariavernon22 @NikkiFried Suuuuuuure, what happend to the dark winter for unvaxxed/unmasked? Oh yeah… https://t.co/6VdUCaGEwz'}
# {'id': 1517185324857937922, 'username': 'BobThomasKNOX', 'created_at': 'Thu Apr 21 16:55:44 +0000 2022', 'lng': -83.9841935, 'lat': 35.815867499999996, 'text': 'Let’s show them how we do it!'}
# {'id': 1517185325449330688, 'username': '___LaReine', 'created_at': 'Thu Apr 21 16:55:44 +0000 2022', 'lng': -72.4511725, 'lat': 43.871756500000004, 'text': 'Did you move out that basement???'}
# {'id': 1517185325445140480, 'username': 'TotalTrafficNYC', 'created_at': 'Thu Apr 21 16:55:44 +0000 2022', 'lng': -73.94949, 'lat': 40.74169, 'text': 'Accident. Two lanes blocked in #AreaofEastRivCrossings on The Queens Midtown Tunnel EB after X14/21st St, stopped t… https://t.co/2r8Rs56QNT'}
# {'id': 1517185325189124104, 'username': 'QueenMatka', 'created_at': 'Thu Apr 21 16:55:44 +0000 2022', 'lng': -119.0376475, 'lat': 35.429265, 'text': 'You took my blood! #MayerJerryDyer #FresnoState #Florida #JusticeForAustin #JerryDyer #FresnoPoliceDepartment… https://t.co/w7fqHQTqDs'}
# {'id': 1517185328246894593, 'username': 'gratefulhike', 'created_at': 'Thu Apr 21 16:55:44 +0000 2022', 'lng': -86.6807375, 'lat': 32.576227, 'text': '@ashbyfrank @603Freeman Opps means potholes, but whatever works, damn edit button'}
# {'id': 1517185331241668611, 'username': 'AmandaSuspended', 'created_at': 'Thu Apr 21 16:55:45 +0000 2022', 'lng': -90.011008, 'lat': 29.982601, 'text': "@FleurdeLindsay Yep. Once I'm triggered, I have a hard time calming down. I've gotten better with anger management but still."}
# {'id': 1517185332348923911, 'username': 'toddforman6', 'created_at': 'Thu Apr 21 16:55:45 +0000 2022', 'lng': -73.4409395, 'lat': 41.1562815, 'text': '@VanessaVaann Hi there baby I’m interested let’s talk chat connect anytime soon thanks todd 203 249 0678'}
# {'id': 1517185333485527040, 'username': 'DeborahTownley5', 'created_at': 'Thu Apr 21 16:55:46 +0000 2022', 'lng': -84.76301000000001, 'lat': 33.3799165, 'text': '@sandibachom Why? REALLY'}
# {'id': 1517185333812613122, 'username': 'Skinny_Black009', 'created_at': 'Thu Apr 21 16:55:46 +0000 2022', 'lng': -122.5889745, 'lat': 45.630589, 'text': 'Now he’s about to stick his dick in his work wife’s ass 🤣🤣🤣'}
# {'id': 1517185335616163846, 'username': 'tmj_brl_recruit', 'created_at': 'Thu Apr 21 16:55:46 +0000 2022', 'lng': -72.5753869, 'lat': 44.2600593, 'text': "We're hiring in #Montpelier, VT! Click the link in our bio to apply to this job and more: Unemployment Hearings Exa… https://t.co/FXfRj0Coxl"}
# {'id': 1517185335729565699, 'username': 'beatgodmilli84', 'created_at': 'Thu Apr 21 16:55:46 +0000 2022', 'lng': -83.1738665, 'lat': 32.6782075, 'text': '@MikeJ21_OT Exactly they be trying Chaney amongst the fanbase but I sit back like watch him run'}
# {'id': 1517185336073342988, 'username': 'tmj_VAL_pharm', 'created_at': 'Thu Apr 21 16:55:46 +0000 2022', 'lng': -76.9832077, 'lat': 38.8060389, 'text': 'This Pharmacy Technician - Retail Store job might be a great fit for you. Click the link in our bio to see it and m… https://t.co/7Bplq1c4hB'}
# {'id': 1517185336610213895, 'username': 'tmj_TX_UTIL', 'created_at': 'Thu Apr 21 16:55:46 +0000 2022', 'lng': -102.6449101, 'lat': 32.7189926, 'text': 'Enterprise Products is hiring in #Seminole, TX! Click the link in our bio to apply: Operator, Pipeline (Hobbs, NM) #operations'}
# {'id': 1517185338053054464, 'username': 'TWALTeth', 'created_at': 'Thu Apr 21 16:55:47 +0000 2022', 'lng': -119.71069449999999, 'lat': 39.574216500000006, 'text': '@tjaychao @WeatheReportNFT Hell yea!!! 🌺 🌦'}
# {'id': 1517185338053054475, 'username': 'tmj_GAS_pharm', 'created_at': 'Thu Apr 21 16:55:47 +0000 2022', 'lng': -81.0933398, 'lat': 32.0245002, 'text': "Want to work at CVS Health? We're hiring in Savannah, GA! Click the link in our bio for details on this job and mor… https://t.co/GKxGCYJdqr"}
# {'id': 1517185339793690626, 'username': 'brittanyvalle_', 'created_at': 'Thu Apr 21 16:55:47 +0000 2022', 'lng': -119.30660750000001, 'lat': 37.2691755, 'text': 'the beach is my happy place'}
# {'id': 1517185339617681408, 'username': 'roswellencina', 'created_at': 'Thu Apr 21 16:55:47 +0000 2022', 'lng': -77.0143985, 'lat': 38.898602999999994, 'text': 'THIS is why we need more LGBTQ+ books and authors. Readers need to see themselves in books. Representation matters.… https://t.co/7W9FEf8MYB'}
# {'id': 1517185340401864705, 'username': 'tmj_vap_retail', 'created_at': 'Thu Apr 21 16:55:47 +0000 2022', 'lng': -76.2858726, 'lat': 36.8507689, 'text': 'See our latest #Norfolk, VA job and click to apply: NOW HIRING Customer Experience Coor - https://t.co/r4ZOqKYlBR #Retail'}
# {'id': 1517185340515110914, 'username': 'HillsboroughPD', 'created_at': 'Thu Apr 21 16:55:47 +0000 2022', 'lng': -122.295229, 'lat': 37.5162205, 'text': 'Happy Birthday 🎉🎈🎂 to our friends at @centralcountyfd !'}
# {'id': 1517185341853155328, 'username': 'jayymariefams', 'created_at': 'Thu Apr 21 16:55:48 +0000 2022', 'lng': -71.054857, 'lat': 42.428694, 'text': "okay i don't know if Space Bunny is Shaggy or Sean Paul and i'm stressed about it. #TheMaskedSinger"}
# {'id': 1517185343149133826, 'username': 'LatanaPowell', 'created_at': 'Thu Apr 21 16:55:48 +0000 2022', 'lng': -122.455344, 'lat': 47.242960499999995, 'text': 'My son, Calvin, 3rd Man down, Black Tshirt, Perfect Son of Mine!!! https://t.co/Bil2biSBk8'}
# {'id': 1517185342482391043, 'username': 'Linzanity143', 'created_at': 'Thu Apr 21 16:55:48 +0000 2022', 'lng': -73.9685415, 'lat': 40.780709, 'text': '@tiva_clois @kat_dobie Happy to die there with you. https://t.co/9Pwlz0GwIU'}
# {'id': 1517185343438655488, 'username': 'SkeelowGME76', 'created_at': 'Thu Apr 21 16:55:48 +0000 2022', 'lng': -85.9785995, 'lat': 35.8305215, 'text': '@coin_trades Algorand is the way... https://t.co/pD0Adn3tBt'}
# {'id': 1517185344759746564, 'username': 'jarmstrongbc', 'created_at': 'Thu Apr 21 16:55:48 +0000 2022', 'lng': -123.123581, 'lat': 49.257639, 'text': 'Hot take: I think this photo is highly unfair to #SmithersBC and is not an equal representation of its beauty 😉'}
# {'id': 1517185345808486400, 'username': 'jakemalasek', 'created_at': 'Thu Apr 21 16:55:49 +0000 2022', 'lng': -73.9685415, 'lat': 40.780709, 'text': '@KFCradio @mikeypavss @JNics415 Pavs you dropped this 👑'}
# {'id': 1517185347029024769, 'username': 'ZekeGary2', 'created_at': 'Thu Apr 21 16:55:49 +0000 2022', 'lng': -120.882482, 'lat': 47.273022, 'text': '@4mojo2 Agree!'}
# {'id': 1517185348643741698, 'username': 'spicynita94', 'created_at': 'Thu Apr 21 16:55:49 +0000 2022', 'lng': -87.732013, 'lat': 41.8335845, 'text': 'ughhhhhhhhhhh them starting this finale w this sex scene is just killing me chile #SnowfallFX'}
# {'id': 1517185351181340674, 'username': 'Sony12Play', 'created_at': 'Thu Apr 21 16:55:50 +0000 2022', 'lng': -84.433106, 'lat': 33.7671945, 'text': "Well Sharon, it's a little too late for this talk with Chelsea. #YR @YandR_CBS"}
# {'id': 1517185351835537409, 'username': 'GetSomeChuck', 'created_at': 'Thu Apr 21 16:55:50 +0000 2022', 'lng': -115.223125, 'lat': 36.232915, 'text': '@TheBeehiveLV @VitalVegas Meh. Been done… and it was awfulhttps://t.co/dJZAEutsUZ'}
# {'id': 1517185352984842241, 'username': 'gillb1414', 'created_at': 'Thu Apr 21 16:55:50 +0000 2022', 'lng': -79.104, 'lat': 43.1234, 'text': 'Check out my #listing in #NiagaraFalls #ON  #realestate #realtor https://t.co/GZbcZL3ETA https://t.co/EnsqssfJAr'}
# {'id': 1517185353873969154, 'username': 'jasmineperalez_', 'created_at': 'Thu Apr 21 16:55:50 +0000 2022', 'lng': -118.4119065, 'lat': 34.0207895, 'text': '@SirAustin11 YOU NEED TO LISTEN TO PARADISE'}
# {'id': 1517185354691977217, 'username': 'kat19477', 'created_at': 'Thu Apr 21 16:55:51 +0000 2022', 'lng': -90.4693135, 'lat': 41.5578115, 'text': '@LizCheney  you have earned this and more.'}
# {'id': 1517185357015568384, 'username': 'Bobby__bitch', 'created_at': 'Thu Apr 21 16:55:51 +0000 2022', 'lng': -98.5406515, 'lat': 29.417501, 'text': 'It is time to finally rip this bandaid off . I know this is going to hurt like a bitch but once the wound heals it’s going to be alright'}
# {'id': 1517185357606899718, 'username': 'ggmrush', 'created_at': 'Thu Apr 21 16:55:51 +0000 2022', 'lng': -122.630908, 'lat': 45.536402, 'text': '@eazybaked @VCTRE_ @playerdavee @EarthGang @DaveChappelle AND @POTUS all in my city at once wowowowoww \U0001fa84\U0001fa84'}
# {'id': 1517185357774831620, 'username': 'BowlPacksTV', 'created_at': 'Thu Apr 21 16:55:51 +0000 2022', 'lng': -70.973641, 'lat': 42.5325755, 'text': '@McDonalds snackwraps baby'}
# {'id': 1517185358794039301, 'username': 'SnSnapShotz', 'created_at': 'Thu Apr 21 16:55:52 +0000 2022', 'lng': -73.9685415, 'lat': 40.780709, 'text': "2 things that everybody is happy didn't happen. Arod and jlo buying the Mets and the jets not paying Jamal Adams 😂"}
# {'id': 1517185358768840704, 'username': 'Gantt4Florida', 'created_at': 'Thu Apr 21 16:55:52 +0000 2022', 'lng': -80.2333285, 'lat': 25.7823535, 'text': 'Join the planning committee by making a contribution of $250 or more at https://t.co/oPL1PBj0xu.RSVP at the link… https://t.co/4L8Kuz79pA'}
# {'id': 1517185360790437889, 'username': 'billtomesch', 'created_at': 'Thu Apr 21 16:55:52 +0000 2022', 'lng': -73.99033656, 'lat': 40.70305698, 'text': 'Just posted a photo @ DUMBO, Brooklyn https://t.co/Nt4FoVptQA'}
# {'id': 1517185361113456640, 'username': 'tideisrising_', 'created_at': 'Thu Apr 21 16:55:52 +0000 2022', 'lng': -87.7588005, 'lat': 41.843776, 'text': 'The urge I have to buy the $109 nightmare before Christmas Punic basket I saw online'}
# {'id': 1517185361155350530, 'username': 'Pelicruise', 'created_at': 'Thu Apr 21 16:55:52 +0000 2022', 'lng': -80.13296249999999, 'lat': 25.816965500000002, 'text': '@Footballville We need everyone to stay fresh and energized, let’s keep stacking the depth!'}
# {'id': 1517185362279473153, 'username': 'GOATunes', 'created_at': 'Thu Apr 21 16:55:52 +0000 2022', 'lng': -79.645081, 'lat': 43.418190499999994, 'text': '@JustinPistachio @BrotherJammer Bettt let’s make it happen'}
# {'id': 1517185361818136577, 'username': 'just_A_sag', 'created_at': 'Thu Apr 21 16:55:52 +0000 2022', 'lng': -98.5406515, 'lat': 29.417501, 'text': 'Alli: mom let me see your card 🤣🤣 https://t.co/kpgTlA8c0B'}
# {'id': 1517185363030249472, 'username': 'BeattyLaw', 'created_at': 'Thu Apr 21 16:55:53 +0000 2022', 'lng': -76.41296349999999, 'lat': 39.3465755, 'text': 'Every single city prosecutor should hear what Thiru just spewed out of his harassment hole on @MiddayWYPR. He lied… https://t.co/kZkKTE2Twi'}
# {'id': 1517185362321362945, 'username': 'GoArmyCinci', 'created_at': 'Thu Apr 21 16:55:52 +0000 2022', 'lng': -84.723474, 'lat': 39.1062675, 'text': '#armyserviceweek is upon us! Tag us in a post if you enlisted from Cincinnati, OH.! https://t.co/UDMXStpZtM'}
# {'id': 1517185364686946304, 'username': 'iHaTeTrUmP4eVeR', 'created_at': 'Thu Apr 21 16:55:53 +0000 2022', 'lng': -77.425155, 'lat': 38.878707500000004, 'text': 'Pay attention...'}
# {'id': 1517185364607352834, 'username': 'KevcoMcdonalds', 'created_at': 'Thu Apr 21 16:55:53 +0000 2022', 'lng': -96.8320095, 'lat': 32.959787500000004, 'text': 'Did you know $100 provides transportation for families to and from area hospitals for one week? Help us… https://t.co/4xoQfsPLxj'}
# {'id': 1517185364976447489, 'username': 'KaylandWLTX', 'created_at': 'Thu Apr 21 16:55:53 +0000 2022', 'lng': -80.926628, 'lat': 33.6311395, 'text': 'The President announces more aid to Ukraine along with a clearer pathway for Ukrainian refugees to seek shelter in… https://t.co/0mOS2pTvUE'}
# {'id': 1517185366524153856, 'username': 'CeeRetise', 'created_at': 'Thu Apr 21 16:55:53 +0000 2022', 'lng': -76.7972215, 'lat': 39.4219875, 'text': 'Happy blessed birthday , @Yamuva_ 🥳✨'}
# {'id': 1517185368063299586, 'username': 'TomTerrific_66', 'created_at': 'Thu Apr 21 16:55:54 +0000 2022', 'lng': -75.093332, 'lat': 39.880914000000004, 'text': '@sunny_Nita_ Always 😊'}
# {'id': 1517185368923295744, 'username': 'Leahmo34', 'created_at': 'Thu Apr 21 16:55:54 +0000 2022', 'lng': -88.5540415, 'lat': 30.3640485, 'text': '@CwrNew Cute video and picture'}
# {'id': 1517185369497903105, 'username': 'clairezagorski', 'created_at': 'Thu Apr 21 16:55:54 +0000 2022', 'lng': -100.0768885, 'lat': 31.1688935, 'text': '@davidfetter Im sure you don’t mean it to, but this reads as a little condescending. I hope I never get to where… https://t.co/awGDGUkwj6'}
# {'id': 1517185369556627457, 'username': 'Kaluakid11', 'created_at': 'Thu Apr 21 16:55:54 +0000 2022', 'lng': -86.441236, 'lat': 39.766555499999996, 'text': 'Problem of living in Bloomington so long, half my snap stories are peoples past little 5’s 😂😂 the pure rachetness t… https://t.co/KczgcpvedB'}
# {'id': 1517185369904758784, 'username': 'LManMatt93', 'created_at': 'Thu Apr 21 16:55:54 +0000 2022', 'lng': -87.732013, 'lat': 41.8335845, 'text': 'Already brought back orange Hi-C so we Gucci'}
# {'id': 1517185371360145411, 'username': 'anthonykriens', 'created_at': 'Thu Apr 21 16:55:55 +0000 2022', 'lng': -93.2620465, 'lat': 44.9706105, 'text': '@JaceFrederick The first round is the best in basketball and hockey'}
# {'id': 1517185372085637137, 'username': 'VinoComitatus', 'created_at': 'Thu Apr 21 16:55:55 +0000 2022', 'lng': -122.16076749999999, 'lat': 47.4506245, 'text': '@SiempreSeattle Peak #FirstWorldProblems you could be in Mariupol or anywhere in Ukraine right now genetic lottery winner. #JustSayin'}
# {'id': 1517185372224114688, 'username': 'ed_swab', 'created_at': 'Thu Apr 21 16:55:55 +0000 2022', 'lng': -88.0222305, 'lat': 43.0061125, 'text': "@FallsAthletics @GCAOWI @GolfKohler Let's go LOW!"}
# {'id': 1517185372169588737, 'username': 'BBWVivienneRose', 'created_at': 'Thu Apr 21 16:55:55 +0000 2022', 'lng': -100.0768885, 'lat': 31.1688935, 'text': "@KeijDrawsBig Yeah fortunately that's the clue everyone has focused on. It also says I have a daughter and have no… https://t.co/0oJxKZC8UV"}
# {'id': 1517185373004189701, 'username': 'rime_salmi', 'created_at': 'Thu Apr 21 16:55:55 +0000 2022', 'lng': -118.48042000000001, 'lat': 34.022688, 'text': '@TheeMrDOZ thank yoooouu 🥰💗'}
# {'id': 1517185375013261312, 'username': 'KayhanLife', 'created_at': 'Thu Apr 21 16:55:56 +0000 2022', 'lng': -118.4119065, 'lat': 34.0207895, 'text': 'April 21 (Reuters)\xa0–\xa0#RamzanKadyrov, head of Russia’s republic of #Chechnya whose forces have been fighting in… https://t.co/AlBVofXVkq'}
# {'id': 1517185375629987841, 'username': 'StarWarsTiffany', 'created_at': 'Thu Apr 21 16:55:56 +0000 2022', 'lng': -94.6750935, 'lat': 38.931549000000004, 'text': 'BIG NEWS! Now that I’ve signed my contract I can announce that I have been hired by https://t.co/AH4HxdedRP as a Li… https://t.co/vB4sJws8pG'}
# {'id': 1517185375885840386, 'username': 'doodoobrown18', 'created_at': 'Thu Apr 21 16:55:56 +0000 2022', 'lng': -76.510792, 'lat': 38.969966, 'text': 'not even being petty tbh.'}
# {'id': 1517185376024203265, 'username': 'dejandabetic', 'created_at': 'Thu Apr 21 16:55:56 +0000 2022', 'lng': -89.5694915, 'lat': 44.900818, 'text': '@theafriyie_ Save them for RG my man'}
# {'id': 1517185376129110017, 'username': 'BrianCarltonVA', 'created_at': 'Thu Apr 21 16:55:56 +0000 2022', 'lng': -79.42086499999999, 'lat': 38.003375500000004, 'text': 'So the plan is to fire journalists due to “budget cuts”… and then hire meteorologists in their place? @LeeEntNews,… https://t.co/odFF1c9SyR'}
# {'id': 1517185376514883584, 'username': 'gnept540', 'created_at': 'Thu Apr 21 16:55:56 +0000 2022', 'lng': -83.1738665, 'lat': 32.6782075, 'text': 'Permanent shmood word to the 🐐 my boy @1future ya heard @GQMagazine https://t.co/xchn1bXKDl'}
# {'id': 1517185377748070401, 'username': 'ArtemisDLW', 'created_at': 'Thu Apr 21 16:55:56 +0000 2022', 'lng': -81.504908, 'lat': 31.2144885, 'text': 'To all PA voters incl Democrats and republican PA votersYou want a hack grifter in Oz or a right-wing hedge fund /… https://t.co/lJtrXISh8J'}
# {'id': 1517185378523893763, 'username': 'tmj_GAD_NURSING', 'created_at': 'Thu Apr 21 16:55:56 +0000 2022', 'lng': -83.2320991, 'lat': 33.0801429, 'text': "Looking to score a job at RHA Health Services? You're in luck. Click the link in our bio for the job description an… https://t.co/16pr5PdseH"}
# {'id': 1517185380273078273, 'username': 'Todd24781926', 'created_at': 'Thu Apr 21 16:55:57 +0000 2022', 'lng': -80.244984, 'lat': 36.087168500000004, 'text': '@Jules31415 @vermont4u @kparker9866 @RepMTG @robbystarbuck @MorganOrtagus Stand up America'}
# {'id': 1517185380822433792, 'username': 'soggycheesefry', 'created_at': 'Thu Apr 21 16:55:57 +0000 2022', 'lng': -82.693149, 'lat': 27.8219585, 'text': 'She put vanilla bean in it btw which is Not That different than the usual Toasted Vanilla but whatever she’s so nic… https://t.co/QN6qRicW92'}
# {'id': 1517185381166305283, 'username': 'tmj_VAA_pharm', 'created_at': 'Thu Apr 21 16:55:57 +0000 2022', 'lng': -76.5498618, 'lat': 39.3664081, 'text': 'At #TeamCVS, we hold ourselves to the highest standards to ensure quality care for all. See how you can make a diff… https://t.co/yGK4czJFVM'}
# {'id': 1517185380512149504, 'username': 'MissRoshni', 'created_at': 'Thu Apr 21 16:55:57 +0000 2022', 'lng': -87.8571075, 'lat': 41.663835500000005, 'text': 'Life was so easy at this age.. #majorthrowback #ThrowbackThursday @ZooTampa https://t.co/9cpPt1mdrC'}
# {'id': 1517185381396992014, 'username': 'tmj_BC_retail', 'created_at': 'Thu Apr 21 16:55:57 +0000 2022', 'lng': -123.4956337, 'lat': 48.4474626, 'text': 'Want to work in #Langford, BC? View our latest opening: https://t.co/OyYBZS6W8d #Retail'}
# {'id': 1517185381422157832, 'username': 'marine5831', 'created_at': 'Thu Apr 21 16:55:57 +0000 2022', 'lng': -118.0767455, 'lat': 33.9072505, 'text': '@MewesFj Those were the days https://t.co/7WiAD2VVX3'}
# {'id': 1517185383531962371, 'username': 'Badgerswimr', 'created_at': 'Thu Apr 21 16:55:58 +0000 2022', 'lng': -88.416258, 'lat': 41.946893, 'text': 'Wheat got down to 1061 quicker than I thought. Chance of weekly reversal just exploded #corn #oatt #soybeans'}
# {'id': 1517185384446406658, 'username': 'SBGriffin', 'created_at': 'Thu Apr 21 16:55:58 +0000 2022', 'lng': -87.9672925, 'lat': 43.0567225, 'text': '@KiKi_Ditto He denies everything. What you mean???'}
# {'id': 1517185388032499712, 'username': 'gaybeatle', 'created_at': 'Thu Apr 21 16:55:59 +0000 2022', 'lng': -73.9685415, 'lat': 40.780709, 'text': 'I want to see Paul’s vest collection'}
# {'id': 1517185389009653772, 'username': 'gascan27', 'created_at': 'Thu Apr 21 16:55:59 +0000 2022', 'lng': -120.882482, 'lat': 47.273022, 'text': 'The arch deluxe. America just wasn’t ready.'}
# {'id': 1517185389508775945, 'username': 'TomAdler', 'created_at': 'Thu Apr 21 16:55:59 +0000 2022', 'lng': -118.325145, 'lat': 34.182159999999996, 'text': '@KeithOlbermann @TuckerCarlson is Gay @RonDeSantisFL'}
# {'id': 1517185391731757071, 'username': 'Courtney_Swink', 'created_at': 'Thu Apr 21 16:55:59 +0000 2022', 'lng': -78.9946395, 'lat': 33.672845499999994, 'text': 'It’s my Birthday!! Can Any of my NASCAR favorites make my day and give me a birthday shout out! Cheers! 🍻… https://t.co/pJ3ErSSF3w'}
# {'id': 1517185392910417921, 'username': 'mb', 'created_at': 'Thu Apr 21 16:56:00 +0000 2022', 'lng': -73.9685415, 'lat': 40.780709, 'text': 'if you thought this meant i was logging off, you extremely don’t know me'}
# {'id': 1517185393300426757, 'username': 'littlemislilli', 'created_at': 'Thu Apr 21 16:56:00 +0000 2022', 'lng': -121.8737305, 'lat': 37.331159, 'text': 'me but also… who fuckin cares nOW???'}
# {'id': 1517185393472393216, 'username': 'melissadeon', 'created_at': 'Thu Apr 21 16:56:00 +0000 2022', 'lng': -92.4367735, 'lat': 38.3045585, 'text': 'The end of one chapter and the beginning of another! You’re looking at the newest employees of @GSBArena ✨✨… https://t.co/M5wasjPb2M'}
# {'id': 1517185396429492230, 'username': 'TJN3', 'created_at': 'Thu Apr 21 16:56:01 +0000 2022', 'lng': -86.2625855, 'lat': 43.161903, 'text': '@mjm52372 I’ll take that Oberon'}
# {'id': 1517185396299509761, 'username': 'BeeSting14618', 'created_at': 'Thu Apr 21 16:56:01 +0000 2022', 'lng': -77.60520650000001, 'lat': 43.1272685, 'text': 'I’m with the surgeon general on this one.'}
# {'id': 1517185396404273153, 'username': 'CarnellRoller2', 'created_at': 'Thu Apr 21 16:56:01 +0000 2022', 'lng': -86.6807375, 'lat': 32.576227, 'text': 'Nice wow'}
# {'id': 1517185397679280134, 'username': 'vera20906333', 'created_at': 'Thu Apr 21 16:56:01 +0000 2022', 'lng': -119.30660750000001, 'lat': 37.2691755, 'text': '@mhdksafa That’s wonderful. I’m happy for you.💐'}
# {'id': 1517185398266642434, 'username': 'beauticheronce', 'created_at': 'Thu Apr 21 16:56:01 +0000 2022', 'lng': -95.44648649999999, 'lat': 29.838495, 'text': 'Where are all the old cooks in Houston … cuz this food ain’t it'}
# {'id': 1517185398442762244, 'username': 'thejoeymak', 'created_at': 'Thu Apr 21 16:56:01 +0000 2022', 'lng': -87.732013, 'lat': 41.8335845, 'text': 'Please fill out @chicago_blend’s survey tracking diversity in leadership at VC-backed companies in Chicagoland (or… https://t.co/Lsk9Sybd7E'}
# {'id': 1517185399243825152, 'username': 'blueeyedsag', 'created_at': 'Thu Apr 21 16:56:01 +0000 2022', 'lng': -97.03971200000001, 'lat': 33.157768000000004, 'text': 'need me a group like this ❤️\u200d🔥'}
# {'id': 1517185400510435331, 'username': 'quistak', 'created_at': 'Thu Apr 21 16:56:02 +0000 2022', 'lng': -159.4625795, 'lat': 21.877461500000003, 'text': "@puwexil It's the Home World theme for me. It's in my head constantly."}
# {'id': 1517185401827516417, 'username': 'RagingR79717523', 'created_at': 'Thu Apr 21 16:56:02 +0000 2022', 'lng': -83.030573, 'lat': 42.581306, 'text': '@Sunnynurses @micheleforfl Remove the muzzle'}
# {'id': 1517185402624487424, 'username': 'Aziztoketrees', 'created_at': 'Thu Apr 21 16:56:02 +0000 2022', 'lng': -95.44648649999999, 'lat': 29.838495, 'text': 'Keep the ganja on me, keep the wax@ home'}
# {'id': 1517185403006205952, 'username': 'JosephMIV466', 'created_at': 'Thu Apr 21 16:56:02 +0000 2022', 'lng': -86.27053950000001, 'lat': 45.001180000000005, 'text': '@RepCawthorn Hmm not really because God has to breathe life unto him/her.  Best to learn your Scripture before clai… https://t.co/NSOYAKp4AP'}
# {'id': 1517185404285427716, 'username': 'MetroGram', 'created_at': 'Thu Apr 21 16:56:02 +0000 2022', 'lng': -93.2620465, 'lat': 44.9706105, 'text': "Wednesday's Wordle 305 4/6SLANTCAMPYCAGEDCARGO ⬜⬜\U0001f7e8⬜⬜\U0001f7e9\U0001f7e9⬜⬜⬜\U0001f7e9\U0001f7e9\U0001f7e8⬜⬜\U0001f7e9\U0001f7e9\U0001f7e9\U0001f7e9\U0001f7e9"}
# {'id': 1517185405610872833, 'username': 'Aye_Shanience', 'created_at': 'Thu Apr 21 16:56:03 +0000 2022', 'lng': -79.85736349999999, 'lat': 36.090396999999996, 'text': 'Today is a half of day for me and ima be at my desk doing my nails the whole time 🤣💅🏽 got my drill and All'}
# {'id': 1517185406613307398, 'username': 'TrillEverything', 'created_at': 'Thu Apr 21 16:56:03 +0000 2022', 'lng': -95.44648649999999, 'lat': 29.838495, 'text': '@blaque_wideaux OMG… 😳😳. I knew I had to do something important today 😅'}
# {'id': 1517185406747516928, 'username': 'Nick_F_Perrelli', 'created_at': 'Thu Apr 21 16:56:03 +0000 2022', 'lng': -73.9487755, 'lat': 40.655138, 'text': 'On todays episode of F*ck around n find out:'}
# {'id': 1517185407544348672, 'username': 'darbgs64', 'created_at': 'Thu Apr 21 16:56:03 +0000 2022', 'lng': -82.44858550000001, 'lat': 28.13173, 'text': 'As long as Dolly and Reba on the list all is well. All of the greats are on that list. Loretta Lynn, Patsy Cline. That’s country.'}
# {'id': 1517185407628169220, 'username': 'TheInfamousEel', 'created_at': 'Thu Apr 21 16:56:03 +0000 2022', 'lng': -122.630908, 'lat': 45.536402, 'text': '@SierraAisling Sad sack shit like Nick Cave and The National. Emotionally and catharsis-wise the opposite of how metal makes me feel'}
# {'id': 1517185406240010240, 'username': 'MarioMarzz', 'created_at': 'Thu Apr 21 16:56:03 +0000 2022', 'lng': -70.9075225, 'lat': 42.515052, 'text': 'APR Thurs Mario Marz HEX Salem Readings In-Store &amp; phone readings 11-7pm #MariomarzcabotHP #witch #HexSalem… https://t.co/OaJkY3jxvO'}
# {'id': 1517185408366432256, 'username': 'gonorm1330', 'created_at': 'Thu Apr 21 16:56:03 +0000 2022', 'lng': -79.42086499999999, 'lat': 38.003375500000004, 'text': '@avgplaya @rocketbotpro @cctip_com Cool 😎'}
# {'id': 1517185408576081923, 'username': 'BroganLL', 'created_at': 'Thu Apr 21 16:56:04 +0000 2022', 'lng': -81.5167515, 'lat': 41.0808775, 'text': '@Traumatyzed_ @tjuicyy_ @chippybtw @IneffableTSloth @ChesneyEA Bro how subway in D?!? You pick your own ingredients'}
# {'id': 1517185408672669698, 'username': 'mrlich', 'created_at': 'Thu Apr 21 16:56:04 +0000 2022', 'lng': -84.612392, 'lat': 34.0110765, 'text': '@natural20shirts I’m with you. It’s the simple little things that just make ALL the difference.'}
# {'id': 1517185408999858176, 'username': 'Pakoyrie1', 'created_at': 'Thu Apr 21 16:56:04 +0000 2022', 'lng': -100.0768885, 'lat': 31.1688935, 'text': 'New Beginnings, New Opportunities and New Peace ! That’s the focus for 2022 💫'}
# {'id': 1517185409058586632, 'username': 'dejithe_x', 'created_at': 'Thu Apr 21 16:56:04 +0000 2022', 'lng': -74.4411045, 'lat': 40.488195000000005, 'text': '@Dafiidiii Some are actually good'}
# {'id': 1517185409159245827, 'username': 'CoachKhalilS', 'created_at': 'Thu Apr 21 16:56:04 +0000 2022', 'lng': -79.42086499999999, 'lat': 38.003375500000004, 'text': 'Congratulations @doryhines on getting the Head Job! If y’all don’t know him, get to know him. Phenomenal person and… https://t.co/eMeWbMPrWT'}
# {'id': 1517185410945863688, 'username': 'ihavenobiasBES2', 'created_at': 'Thu Apr 21 16:56:04 +0000 2022', 'lng': -122.14403, 'lat': 37.414371, 'text': 'SM FAAAAAAAM'}
# {'id': 1517185411856146432, 'username': 'GmanMU09', 'created_at': 'Thu Apr 21 16:56:04 +0000 2022', 'lng': -82.4398345, 'lat': 38.407664, 'text': 'Its evident the trend of smart, self help books, is by photo posting only.Evidenced by the same people making the… https://t.co/4JQVppAk98'}
# {'id': 1517185412007178241, 'username': 'GillieHicks', 'created_at': 'Thu Apr 21 16:56:04 +0000 2022', 'lng': -93.04028149999999, 'lat': 44.8838495, 'text': 'You want the crown but down know what it takes'}
# {'id': 1517185413953339396, 'username': 'Arich1028', 'created_at': 'Thu Apr 21 16:56:05 +0000 2022', 'lng': -74.066663, 'lat': 40.7180015, 'text': 'https://t.co/TvGQDknx60mood'}
# {'id': 1517185414267752456, 'username': 'RoaneSymon', 'created_at': 'Thu Apr 21 16:56:05 +0000 2022', 'lng': -119.2289915, 'lat': 34.289689499999994, 'text': '@RahsaanSalaam What a sexual creature JD is 😜 😛 🤪 😝 🤑 😜'}
# {'id': 1517185415886819329, 'username': 'TomOestreich', 'created_at': 'Thu Apr 21 16:56:05 +0000 2022', 'lng': -86.13244850000001, 'lat': 39.9632495, 'text': 'It’s been an exciting day in @myccs honoring and recognizing our Elementary Teachers of the Year and Support Staff… https://t.co/lXcw7X94n9'}
# {'id': 1517185416306253826, 'username': 'UranusComics', 'created_at': 'Thu Apr 21 16:56:05 +0000 2022', 'lng': -73.9487755, 'lat': 40.655138, 'text': 'Cropping some old photos from 2004 #tbt https://t.co/jG4JQvRlOB'}
# {'id': 1517185416654430211, 'username': 'HelicoptersofDC', 'created_at': 'Thu Apr 21 16:56:05 +0000 2022', 'lng': -77.0900964, 'lat': 38.83851989, 'text': '.@LucyAppa spotted an H60 and has 2616 points 🥇 #CopterSpotter Probable operators: Army/National Guard/FBI/Possibly… https://t.co/nNtvMcIC9j'}
# {'id': 1517185418235629570, 'username': 'Mark215Oliveras', 'created_at': 'Thu Apr 21 16:56:06 +0000 2022', 'lng': -82.114383, 'lat': 41.3608395, 'text': '@FrankieJGrande @Nickelodeon Ready to watch you Tear Some Shit Up like Terry Labonte tonight as Frankini!'}
# {'id': 1517185418818572291, 'username': 'TravelTacoma', 'created_at': 'Thu Apr 21 16:56:06 +0000 2022', 'lng': -122.427259, 'lat': 47.236654, 'text': 'This week we are celebrating this iconic piece of Tacoma. A dome of our own! 39 years of events and celebrations ha… https://t.co/7HJdlRii7b'}
# {'id': 1517185420169252865, 'username': 'mercmaniac64', 'created_at': 'Thu Apr 21 16:56:06 +0000 2022', 'lng': -81.9215795, 'lat': 41.4445855, 'text': '@RossJeffery_ @tjoneswriter @CemeteryGatesM Ross, he has such sights to show you…'}
# {'id': 1517185420198498317, 'username': 'tmj_ky_sales', 'created_at': 'Thu Apr 21 16:56:06 +0000 2022', 'lng': -85.7584557, 'lat': 38.2526647, 'text': 'See our latest Louisville, KY #Sales job opportunity and click the link in our bio to apply: Inside Sales Represent… https://t.co/1L3U7nIfrU'}
# {'id': 1517185420232052745, 'username': 'HCSG', 'created_at': 'Thu Apr 21 16:56:06 +0000 2022', 'lng': -80.8431267, 'lat': 35.2270869, 'text': 'Join the Hoist &amp; Crane Service Group team! See our latest job opening here: https://t.co/3dBXmihPuM #apprentice #Charlotte, NC'}
# {'id': 1517185420462739465, 'username': 'ID_physician', 'created_at': 'Thu Apr 21 16:56:06 +0000 2022', 'lng': -112.0339645, 'lat': 43.4916514, 'text': 'HCA Healthcare is looking for teammates like you. See our latest Physician / Surgeon.Hematology / Oncology.General… https://t.co/4qQ92hEgZX'}
# {'id': 1517185420404019204, 'username': 'quis__custodiet', 'created_at': 'Thu Apr 21 16:56:06 +0000 2022', 'lng': -118.26457, 'lat': 34.05579, 'text': '1655ZN472LA LAPD AIR SUPPORT DIVISIONN34.0558 W118.2646Altitude: 900ftCourse: 72ºGroundspeed: 80kts https://t.co/qZu8IP3xwM'}
# {'id': 1517185421012193281, 'username': 'MarlishGambino', 'created_at': 'Thu Apr 21 16:56:06 +0000 2022', 'lng': -119.30660750000001, 'lat': 37.2691755, 'text': '@BeetCornFarm @ThisIs1984_ @ThommyB8 @Cernovich @elonmusk Haha so something he announced yesterday,  4 days after m… https://t.co/vXcP7e9Fw8'}
# {'id': 1517185421523898377, 'username': 'tmj_phx_transp', 'created_at': 'Thu Apr 21 16:56:07 +0000 2022', 'lng': -112.3496021, 'lat': 33.4355977, 'text': "If you're looking for work in #Avondale, AZ, check out this #Transportation job via the link in our bio: Parts Deli… https://t.co/GWhEMqx448"}
# {'id': 1517185421662310405, 'username': 'tmj_njs_retail', 'created_at': 'Thu Apr 21 16:56:07 +0000 2022', 'lng': -74.922302, 'lat': 39.784496, 'text': 'Can you recommend anyone for this #Retail job in #Berlin, NJ? Click the link in our bio to see it and more. SALES A… https://t.co/IUdNZlLAtJ'}
# {'id': 1517185420727099393, 'username': 'singerwriterEFA', 'created_at': 'Thu Apr 21 16:56:06 +0000 2022', 'lng': -88.245392, 'lat': 40.116932, 'text': 'Love being back at @ebertfest again!  #ebertfest2022 https://t.co/oZNP2JqzxF'}
# {'id': 1517185421276434440, 'username': 'dave_schilling', 'created_at': 'Thu Apr 21 16:56:07 +0000 2022', 'lng': -118.4119065, 'lat': 34.0207895, 'text': 'Mario’s plumbing business got hit hard by supply chain issues and he hasn’t been working much. https://t.co/Q1IhwtLDuP'}
# {'id': 1517185423268728843, 'username': 'is250julian', 'created_at': 'Thu Apr 21 16:56:07 +0000 2022', 'lng': -121.8737305, 'lat': 37.331159, 'text': 'FRANKLIN SAINT'}
# {'id': 1517185423356874753, 'username': 'hanifsahib', 'created_at': 'Thu Apr 21 16:56:07 +0000 2022', 'lng': -73.829384, 'lat': 40.912499, 'text': '@CMShehbaz  Ghus patio  get off.@ImranKhanPTI#امپورٹڈ_حکومت_نامنظور'}
# {'id': 1517185424342536192, 'username': 'wurfbaumamy1', 'created_at': 'Thu Apr 21 16:56:07 +0000 2022', 'lng': -73.900329, 'lat': 41.7919415, 'text': '@hakahaka @ejustin46 @morgfair @SamRamani2 That’s unfortunately the case in many situations. People were afraid aft… https://t.co/OFBDA5A0EJ'}
# {'id': 1517185424262848513, 'username': 'texanpatriot1', 'created_at': 'Thu Apr 21 16:56:07 +0000 2022', 'lng': -97.4636445, 'lat': 35.327467999999996, 'text': '....alright $MAHAWho is the mystery buyer 🤣@CryptoMedic4 https://t.co/7QzbnksBnm'}
# {'id': 1517185424736890880, 'username': 'CampbellSports', 'created_at': 'Thu Apr 21 16:56:07 +0000 2022', 'lng': -85.40414150000001, 'lat': 38.7662295, 'text': "How his career didn't end after that debacle is one of life's mysteries."}
# {'id': 1517185425290547200, 'username': 'RickAndrew16', 'created_at': 'Thu Apr 21 16:56:07 +0000 2022', 'lng': -83.7289515, 'lat': 42.47749, 'text': '@maddyskorupski5 @MSU_WBasketball @SuzyMerchant WOW!!!!!!!!!!!!🐐🏀🐐Congrats!'}
# {'id': 1517185426192465920, 'username': 'HSOWBRolo', 'created_at': 'Thu Apr 21 16:56:08 +0000 2022', 'lng': -83.0269885, 'lat': 42.492846, 'text': '@olgatokariuk @olya_rudenko @expatua I have PayPal. I will donate as soon as I get back in my office!'}
# {'id': 1517185427521867776, 'username': 'Feinomadeit', 'created_at': 'Thu Apr 21 16:56:08 +0000 2022', 'lng': -76.66458092, 'lat': 39.30476775, 'text': 'Just posted a photo @ Ghetto Streets Of Baltimore https://t.co/oRpwgDpTax'}
# {'id': 1517185429686132737, 'username': 'MaxJSEsq', 'created_at': 'Thu Apr 21 16:56:09 +0000 2022', 'lng': -83.804475, 'lat': 27.698681999999998, 'text': 'Our legal writing icon https://t.co/fBwZ2ziX6n'}
# {'id': 1517185429983961094, 'username': 'treykellybell', 'created_at': 'Thu Apr 21 16:56:09 +0000 2022', 'lng': -76.62048200000001, 'lat': 39.284712999999996, 'text': 'Or. just say no… I’m in a relationship… I don’t have no minutes right now… say “give me yours instead” and never ca… https://t.co/PTS1eAGAjD'}
# {'id': 1517185431120465924, 'username': 'OC_Investigator', 'created_at': 'Thu Apr 21 16:56:09 +0000 2022', 'lng': -117.7300055, 'lat': 33.560742000000005, 'text': '@UCPD_Cal At Cesar Chavez building'}
# {'id': 1517185432282357760, 'username': 'MoonlightCiara', 'created_at': 'Thu Apr 21 16:56:09 +0000 2022', 'lng': -73.8311875, 'lat': 40.6708795, 'text': '@sbedaux Love this collection… so happy I own one!'}
# {'id': 1517185431514882049, 'username': 'CoastHusky', 'created_at': 'Thu Apr 21 16:56:09 +0000 2022', 'lng': -77.0143985, 'lat': 38.898602999999994, 'text': '@RobicanAmican Aww, Thank you. ❤️'}
# {'id': 1517185433368682497, 'username': 'iam_Beasty', 'created_at': 'Thu Apr 21 16:56:09 +0000 2022', 'lng': -81.65553, 'lat': 30.324331, 'text': 'Today will be great 🥰'}
# {'id': 1517185433297371139, 'username': 'M4G3RK', 'created_at': 'Thu Apr 21 16:56:09 +0000 2022', 'lng': -100.0768885, 'lat': 31.1688935, 'text': 'SeinfeldSimpsons(seasons 3-9)The WireBreaking BadMindhunterHappy EndingsDeadwoodThe SopranosGilmore GirlsM… https://t.co/Q4SuPy5SNS'}
# {'id': 1517185435495239682, 'username': 'IanLogan3', 'created_at': 'Thu Apr 21 16:56:10 +0000 2022', 'lng': -79.3288235, 'lat': 43.0373535, 'text': "@AubriePesky What could go wrong? It's a can't lose proposition."}
# {'id': 1517185436296237065, 'username': 'Natesbarbersho1', 'created_at': 'Thu Apr 21 16:56:10 +0000 2022', 'lng': -122.4359785, 'lat': 37.7706565, 'text': 'LOVE THIS'}
# {'id': 1517185436539658241, 'username': 'Jim_n_Texas', 'created_at': 'Thu Apr 21 16:56:10 +0000 2022', 'lng': -95.44648649999999, 'lat': 29.838495, 'text': '@GOP Explain how you’re arriving at that??? 😬🤔'}
# {'id': 1517185436959006722, 'username': 'jessunee', 'created_at': 'Thu Apr 21 16:56:10 +0000 2022', 'lng': -74.066663, 'lat': 40.7180015, 'text': 'i was going crazy when she performed this— everyone was.'}
# {'id': 1517185437797961729, 'username': 'JordanSnugs', 'created_at': 'Thu Apr 21 16:56:10 +0000 2022', 'lng': -100.0768885, 'lat': 31.1688935, 'text': '@iizz_savage Absolutely beautiful 🤩💕'}
# {'id': 1517185439261675524, 'username': 'JiggyRiz', 'created_at': 'Thu Apr 21 16:56:11 +0000 2022', 'lng': -74.15394699999999, 'lat': 40.572376000000006, 'text': 'Really Have to Cancel My Trip To Costa Rica.'}
# {'id': 1517185439467192321, 'username': 'DSRawxXx', 'created_at': 'Thu Apr 21 16:56:11 +0000 2022', 'lng': -95.44648649999999, 'lat': 29.838495, 'text': '@miss_pame22 Hey are u open to a shoot 📸 do u have an email we can discuss or can we DM here ?  @miss_pame22'}
# {'id': 1517185439811063821, 'username': 'pietowntv', 'created_at': 'Thu Apr 21 16:56:11 +0000 2022', 'lng': -87.732013, 'lat': 41.8335845, 'text': "🌳TONIGHT🌳 on #HouseHunters ~ A Chicagoan wants to move out of his ex's apartment building and into a home of his ow… https://t.co/hXzN4N2HWl"}
# {'id': 1517185441094582274, 'username': '_VMichelle_', 'created_at': 'Thu Apr 21 16:56:11 +0000 2022', 'lng': -89.92202900000001, 'lat': 35.1335205, 'text': 'one thing about it, ima check my bank accounts daily to make sure ain’t nobody stealing from me😂'}
# {'id': 1517185440822013952, 'username': 'IFLYSwimClub', 'created_at': 'Thu Apr 21 16:56:11 +0000 2022', 'lng': -91.53706199999999, 'lat': 41.6473535, 'text': 'Congratulations to Holden Carter for being selected by @usaswimming to attend the Regional Diversity Select Camp! https://t.co/hl1LsZIk4g'}
# {'id': 1517185441635704835, 'username': 'TheFamily_bball', 'created_at': 'Thu Apr 21 16:56:11 +0000 2022', 'lng': -81.3775, 'lat': 28.5421, 'text': 'Small ⭕️ but you get the picture. We coming for more. All groups in Indy this weekend, 15u, 16u, and 17u. Open peri… https://t.co/Y9pCTrs6I9'}
# {'id': 1517185441820295171, 'username': 'soldier3058', 'created_at': 'Thu Apr 21 16:56:11 +0000 2022', 'lng': -73.8311875, 'lat': 40.6708795, 'text': "@JRSportBrief If you didn't know, Mike aint the one to be played with🤣🤣🤣 https://t.co/gHcxdycYlC"}
# {'id': 1517185441480396813, 'username': 'aramisx', 'created_at': 'Thu Apr 21 16:56:11 +0000 2022', 'lng': -117.76741, 'lat': 33.658649, 'text': 'I’ve missed my desk. Not back just yet but working on campus for some stuff and things this week. https://t.co/aww04inkNG'}
# {'id': 1517185442277380100, 'username': 'Ricka168', 'created_at': 'Thu Apr 21 16:56:12 +0000 2022', 'lng': -82.67290299999999, 'lat': 27.7957195, 'text': '@catwalkb9 followed..fb https://t.co/8SlQU2V4nL'}
# {'id': 1517185442805858306, 'username': 'ButYOUKnew_', 'created_at': 'Thu Apr 21 16:56:12 +0000 2022', 'lng': -86.7779855, 'lat': 35.9952715, 'text': 'Got training all next week to get this certification with the state.. I’ll be a Certified Peer Recovery Specialist by wks end.'}
# {'id': 1517185443938422784, 'username': 'courtneybhilton', 'created_at': 'Thu Apr 21 16:56:12 +0000 2022', 'lng': -71.112377, 'lat': 42.3781975, 'text': '@petejvickers Left'}
# {'id': 1517185443414126593, 'username': 'MadHatterNvrSlp', 'created_at': 'Thu Apr 21 16:56:12 +0000 2022', 'lng': -73.9487755, 'lat': 40.655138, 'text': 'After seeing #TakeMeOut, I feel like I need to go hard at the gym. I had a good time though. https://t.co/jDSD46pQuR'}
# {'id': 1517185445293019139, 'username': 'jjocce_', 'created_at': 'Thu Apr 21 16:56:12 +0000 2022', 'lng': -112.4249755, 'lat': 33.4128725, 'text': 'Some girl flipped me off for “cutting her off” but the lane literally merges lmao y’all some goofies fr'}
# {'id': 1517185445049864192, 'username': 'brookerturner73', 'created_at': 'Thu Apr 21 16:56:12 +0000 2022', 'lng': -87.893924, 'lat': 42.036141, 'text': '@GiveAwayHost @Cryptoxlili Good luck everyone https://t.co/YqtDLvwbjR'}
# {'id': 1517185445288988679, 'username': 'tavoadan', 'created_at': 'Thu Apr 21 16:56:12 +0000 2022', 'lng': -80.1223555, 'lat': 26.301198, 'text': 'Almost Friday https://t.co/hYe11HX69T'}
# {'id': 1517185446756896769, 'username': 'jeffkahrs', 'created_at': 'Thu Apr 21 16:56:13 +0000 2022', 'lng': -81.152424, 'lat': 33.978216, 'text': "@Anti_twatwaffle at least you haven't gone full Heard...gone being the operative word"}
# {'id': 1517185446899552256, 'username': 'DamnThatsKey', 'created_at': 'Thu Apr 21 16:56:13 +0000 2022', 'lng': -84.433106, 'lat': 33.7671945, 'text': 'No fr. It be uncomfortable asf 😂'}
# {'id': 1517185447142825984, 'username': 'BarreraGabe', 'created_at': 'Thu Apr 21 16:56:13 +0000 2022', 'lng': -83.804475, 'lat': 27.698681999999998, 'text': 'My Message to The close mind ignorant Republicans https://t.co/RpOuQB9n4G'}
# {'id': 1517185448409505794, 'username': 'sportsguymarv', 'created_at': 'Thu Apr 21 16:56:13 +0000 2022', 'lng': -83.641199, 'lat': 32.58263, 'text': 'Hey NEWSIES lol this is what they think of us 😂😂😂 https://t.co/P3z7xiMvwa'}
# {'id': 1517185449499906087, 'username': 'ZekeGary2', 'created_at': 'Thu Apr 21 16:56:13 +0000 2022', 'lng': -120.882482, 'lat': 47.273022, 'text': '@4mojo2 Nope'}
# {'id': 1517185449600729088, 'username': 'TuddleOnRadio', 'created_at': 'Thu Apr 21 16:56:13 +0000 2022', 'lng': -81.29165950000001, 'lat': 29.017060999999998, 'text': '@Kenny_Wallace Depends on how loud the 25% are'}
# {'id': 1517185449252507648, 'username': 'William46676045', 'created_at': 'Thu Apr 21 16:56:13 +0000 2022', 'lng': -83.3997795, 'lat': 33.9563835, 'text': "Underrated receiver back in the 1990's Eric Moulds! https://t.co/JSqV03yutT"}
# {'id': 1517185449948848130, 'username': 'alexistameka', 'created_at': 'Thu Apr 21 16:56:13 +0000 2022', 'lng': -87.732013, 'lat': 41.8335845, 'text': 'I need something scary to watch but I can’t find nothing on Hulu or Netflix'}
# {'id': 1517185450301173760, 'username': 'lentaminen', 'created_at': 'Thu Apr 21 16:56:13 +0000 2022', 'lng': -115.147599, 'lat': 36.081, 'text': '#LAS is currently experiencing departure delays between 16 mins and 30 mins due to RWY:Disabled Aircraft… https://t.co/3hfJdN20Jc'}
# {'id': 1517185450380771328, 'username': 'mrsharma', 'created_at': 'Thu Apr 21 16:56:13 +0000 2022', 'lng': -73.9685415, 'lat': 40.780709, 'text': '@itsOddit Any @ILLENIUM mix honestly https://t.co/PFYpPdQsPK'}
# {'id': 1517185450741420040, 'username': 'TattedUpMiko', 'created_at': 'Thu Apr 21 16:56:14 +0000 2022', 'lng': -117.0226945, 'lat': 38.502147, 'text': 'Lemme get up so I can spread my love "correctly" 😭😭😭 https://t.co/ebD9nidQyi'}
# {'id': 1517185451030896640, 'username': 'ModernDay_Griot', 'created_at': 'Thu Apr 21 16:56:14 +0000 2022', 'lng': -87.732013, 'lat': 41.8335845, 'text': 'We don’t want money that fits in a bag, we want the bank. 🏦'}
# {'id': 1517185451421057024, 'username': 'ChrisGhent', 'created_at': 'Thu Apr 21 16:56:14 +0000 2022', 'lng': -73.9487755, 'lat': 40.655138, 'text': '@ianDAOs @elonmusk @jack That roadmap would be cool to know… a DAO could be raised and crowdfunded as opposed to ju… https://t.co/SurdxRYovF'}
# {'id': 1517185454898139140, 'username': 'GBraggsJr23', 'created_at': 'Thu Apr 21 16:56:15 +0000 2022', 'lng': -87.732013, 'lat': 41.8335845, 'text': 'Pregame for @CHGO_WhiteSox at the plate. ⚾️ @CHGO_Sports with @KevinKaduk, @Ecnerwal23 &amp; @JakeFlannigan on deck!… https://t.co/bdGMDFOkPA'}
# {'id': 1517185456580042752, 'username': 'charlie13blue', 'created_at': 'Thu Apr 21 16:56:15 +0000 2022', 'lng': -83.1738665, 'lat': 32.6782075, 'text': '@AuthorErinChase If you have to ask...'}
# {'id': 1517185456760307712, 'username': '1045TheZone', 'created_at': 'Thu Apr 21 16:56:15 +0000 2022', 'lng': -86.791549, 'lat': 36.200008, 'text': 'Mike Vrabel: “Caleb Farley is lightyears ahead right now compared to where he was at the end of last season.” #Titans'}
# {'id': 1517185457095909382, 'username': '511NY', 'created_at': 'Thu Apr 21 16:56:15 +0000 2022', 'lng': -73.646725, 'lat': 41.007975, 'text': 'Cleared: Construction on #I95 SB at 0.11 miles before Exit 2 (LOUDEN ST)'}
# ...
# {'id': 1517185521252024333, 'username': 'Johnnywaynes', 'created_at': 'Thu Apr 21 16:56:30 +0000 2022', 'lng': -77.60468399999999, 'lat': 41.1179365, 'text': '@ochocinco Bo Jackson'}
# {'id': 1517185521692389377, 'username': 'sheabsullivan', 'created_at': 'Thu Apr 21 16:56:30 +0000 2022', 'lng': -95.44648649999999, 'lat': 29.838495, 'text': '@2017Simp Feeling this 💯 today'}
# {'id': 1517185522032005143, 'username': 'susiefreathy', 'created_at': 'Thu Apr 21 16:56:31 +0000 2022', 'lng': -116.9880225, 'lat': 32.85118, 'text': "@KerryAnnAnn @Manning4USCong @Surgeon_General Name calling, misogyny, and racism are all they've got."}
# {'id': 1517185523609214977, 'username': 'SeeSotos_world', 'created_at': 'Thu Apr 21 16:56:31 +0000 2022', 'lng': -73.86085700000001, 'lat': 40.944567500000005, 'text': 'I go weeks with out a drink and then when i drink … i really drink. This feels like a responsible adult. I dont kno… https://t.co/NS8QRMzBNO'}
# {'id': 1517185523768598536, 'username': 'gonorm1330', 'created_at': 'Thu Apr 21 16:56:31 +0000 2022', 'lng': -79.42086499999999, 'lat': 38.003375500000004, 'text': '@TanoliPak24 @rocketbotpro Cool 😎'}
# {'id': 1517185525031084032, 'username': 'DocLauraB', 'created_at': 'Thu Apr 21 16:56:31 +0000 2022', 'lng': -85.7223455, 'lat': 38.195555, 'text': 'Not Nana!!! But seriously, this is how working on publications feels.'}
# {'id': 1517185524792020992, 'username': 'timnphilly', 'created_at': 'Thu Apr 21 16:56:31 +0000 2022', 'lng': -75.117998, 'lat': 40.0048655, 'text': "I’m still stuck in the 80s with #AppleMusic. Classic—#WhiteLionLet's all join our hands,raise them togetherFight… https://t.co/Hzf6IsxfZG"}
# {'id': 1517185527367282688, 'username': 'samtosane', 'created_at': 'Thu Apr 21 16:56:32 +0000 2022', 'lng': -75.4660545, 'lat': 40.257594499999996, 'text': "@hun_chooo @KingZilch @nytimes They are in Putin's pocket so that' why they met with him.  Biden got Germany to shut down the pipeline."}
# {'id': 1517185529221201922, 'username': 'MikeDury', 'created_at': 'Thu Apr 21 16:56:32 +0000 2022', 'lng': -82.985772, 'lat': 39.9946835, 'text': 'It’s going to be a bloodbath.'}
# {'id': 1517185529594335244, 'username': 'Tarek53180', 'created_at': 'Thu Apr 21 16:56:32 +0000 2022', 'lng': -122.2329345, 'lat': 37.4972935, 'text': '@VeronicaDLCruz Pretty in pink https://t.co/eWMScYylM4'}
# {'id': 1517185530693304323, 'username': 'golftimbercreek', 'created_at': 'Thu Apr 21 16:56:33 +0000 2022', 'lng': -87.85750066, 'lat': 30.6692187, 'text': 'Just posted a photo @ TimberCreek Golf Club https://t.co/UJbWSpwyvH'}
# {'id': 1517185529665638401, 'username': 'WorldDanceCo', 'created_at': 'Thu Apr 21 16:56:32 +0000 2022', 'lng': -122.755776, 'lat': 49.285458500000004, 'text': '📣 Youth Latin Ballroom Sundays - 12-1pm***1st class is FREE***With Alexey &amp; Vlada 🏆🍀$64/month 🍀 World 🌎 Danc… https://t.co/yICLUSYh9r'}
# {'id': 1517185531834216450, 'username': 'chrystal_inno', 'created_at': 'Thu Apr 21 16:56:33 +0000 2022', 'lng': -73.8311875, 'lat': 40.6708795, 'text': 'White Americans have slightly more knowledge about Africa than African Americans. On average'}
# {'id': 1517185532266270720, 'username': 'RetireManifesto', 'created_at': 'Thu Apr 21 16:56:33 +0000 2022', 'lng': -83.1738665, 'lat': 32.6782075, 'text': '@AcdntlyRetired Never stop learning.'}
# {'id': 1517185532190773249, 'username': 'Darlene01631927', 'created_at': 'Thu Apr 21 16:56:33 +0000 2022', 'lng': -83.9638415, 'lat': 35.9824705, 'text': 'A name that suits you, Fried.'}
# {'id': 1517185533134397440, 'username': 'colonialsmokes', 'created_at': 'Thu Apr 21 16:56:33 +0000 2022', 'lng': -71.401414, 'lat': 42.462537499999996, 'text': 'Also this! https://t.co/AcAAmbYhKa'}
# {'id': 1517185533272801280, 'username': 'dild0sNcupcakes', 'created_at': 'Thu Apr 21 16:56:33 +0000 2022', 'lng': -105.5508905, 'lat': 38.997935999999996, 'text': 'She’s a legend.'}
# {'id': 1517185533868453888, 'username': 'general_devs89', 'created_at': 'Thu Apr 21 16:56:33 +0000 2022', 'lng': -74.1561685, 'lat': 40.95898, 'text': '@ThatsJustPr1me Definitely. No doubt he deserved what he got.'}
# {'id': 1517185533822357506, 'username': 'therealADWarren', 'created_at': 'Thu Apr 21 16:56:33 +0000 2022', 'lng': -85.7682405, 'lat': 37.822244, 'text': "#Calipari has taken his one and done to a new level.  None and done.He has destroyed the UK mbb team.I've argued… https://t.co/izWDCW3Lzo"}
# {'id': 1517185534078169092, 'username': 'AsherHBaron', 'created_at': 'Thu Apr 21 16:56:33 +0000 2022', 'lng': -73.9685415, 'lat': 40.780709, 'text': 'So, I lost an (yes, just the 1) AirPod. It’s made my life a BIT of a struggle. I was due for an upgrade so I ordere… https://t.co/3sspa8XsUP'}
# {'id': 1517185533746847744, 'username': 'EdmistonDavid', 'created_at': 'Thu Apr 21 16:56:33 +0000 2022', 'lng': -83.3997795, 'lat': 33.9563835, 'text': '@kasediehl44 exposed https://t.co/nCGPkX0lxK'}
# {'id': 1517185535084679172, 'username': '_krisroman_', 'created_at': 'Thu Apr 21 16:56:34 +0000 2022', 'lng': -117.397616, 'lat': 33.935822, 'text': 'IM PETTY AF ✨…I need to work on that lol https://t.co/GYMY1p1iHq'}
# {'id': 1517185536770789386, 'username': 'IsisWise', 'created_at': 'Thu Apr 21 16:56:34 +0000 2022', 'lng': -123.123581, 'lat': 49.257639, 'text': 'My bet’s on #JustIncredible       RT'}
# {'id': 1517185536498229248, 'username': 'steadyfreddyETH', 'created_at': 'Thu Apr 21 16:56:34 +0000 2022', 'lng': -100.0768885, 'lat': 31.1688935, 'text': 'Love your work and watching you grow and succeed 💚 @rocsolmiami https://t.co/uIYQq1W0W5'}
# {'id': 1517185537643270145, 'username': 'Reesegawd_', 'created_at': 'Thu Apr 21 16:56:34 +0000 2022', 'lng': -87.732013, 'lat': 41.8335845, 'text': '@AyeTribeCalledQ Fuck you going in a big ass hummer 😂'}
# {'id': 1517185538318557185, 'username': 'JonnyGlessner', 'created_at': 'Thu Apr 21 16:56:34 +0000 2022', 'lng': -98.319925, 'lat': 38.498196, 'text': 'Summer camp in Alva, OK today!'}
# {'id': 1517185538696089600, 'username': 'jdpandoo', 'created_at': 'Thu Apr 21 16:56:35 +0000 2022', 'lng': -102.344087, 'lat': 31.873838499999998, 'text': 'it did until i had hives all of my face and was in pain at the lake for DAYS \U0001f979'}
# {'id': 1517185541594398720, 'username': 'NiceDrewishFela', 'created_at': 'Thu Apr 21 16:56:35 +0000 2022', 'lng': -80.926628, 'lat': 33.6311395, 'text': "@tedcruz Ted Cruz hasn't done his job once this year. Why?"}
# {'id': 1517185543876055043, 'username': 'goopeerr2', 'created_at': 'Thu Apr 21 16:56:36 +0000 2022', 'lng': -93.1056485, 'lat': 44.9415155, 'text': 'is your micriwave running?'}
# {'id': 1517185544555577344, 'username': 'trentnrobison', 'created_at': 'Thu Apr 21 16:56:36 +0000 2022', 'lng': -80.295886, 'lat': 25.711706, 'text': 'most people are the same. hard to find unique.'}
# {'id': 1517185545130037249, 'username': 'anagoonz', 'created_at': 'Thu Apr 21 16:56:36 +0000 2022', 'lng': -117.104989, 'lat': 32.810012, 'text': 'my lust for shiny things'}
# {'id': 1517185545255927810, 'username': 'uindyhound', 'created_at': 'Thu Apr 21 16:56:36 +0000 2022', 'lng': -86.1429225, 'lat': 39.7795625, 'text': 'I love hearing @UIndyAlumni stories!#greyhoundsforever #uindyday 🐾❤️'}
# {'id': 1517185545432182784, 'username': 'SaintADW', 'created_at': 'Thu Apr 21 16:56:36 +0000 2022', 'lng': -84.3064885, 'lat': 33.9430725, 'text': "#JordanCon2022 who's down for some lunch? Mustering the posse, waiting for @robchristianson to get here, then the t… https://t.co/ztCEAjzVck"}
# {'id': 1517185545964769280, 'username': 'lavie154', 'created_at': 'Thu Apr 21 16:56:36 +0000 2022', 'lng': -83.804475, 'lat': 27.698681999999998, 'text': '@bassusteur canon chads only here'}
# {'id': 1517185546728222720, 'username': 'georgehahn', 'created_at': 'Thu Apr 21 16:56:36 +0000 2022', 'lng': -73.9685415, 'lat': 40.780709, 'text': 'What Scott said. Very grateful to have been included for a minute. Everything is temporary. #CNNplus'}
# {'id': 1517185547139108865, 'username': 'shindoverse', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -117.104989, 'lat': 32.810012, 'text': 'Humans are stuck in the past… I kept thinking of DS9’s “The Emissary” where the Prophets tell Sisko he exists in th… https://t.co/5WkoinnEMj'}
# {'id': 1517185547629842441, 'username': 'bichonsw0rld', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -118.4119065, 'lat': 34.0207895, 'text': 'mems ✨'}
# {'id': 1517185547520942080, 'username': 'NWJS_jobs', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -106.826452, 'lat': 39.194434, 'text': 'Check out the latest opening https://t.co/QETw33dTKY at The Aspen Times in Aspen, CO. Journalismjobs'}
# {'id': 1517185547986358272, 'username': 'MalexNM', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -106.662024, 'lat': 35.296183, 'text': "@LilCupcake331 I'm so sorry. My thoughts are with you ♥️"}
# {'id': 1517185548137414656, 'username': 'taranwalker', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -90.5812485, 'lat': 38.651686999999995, 'text': 'Putting ads in F2P games makes perfect sense.'}
# {'id': 1517185547797737474, 'username': 'DrunkAtdisney', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -81.40234699999999, 'lat': 28.299370500000002, 'text': '@derekburgan @EricBurrisWESH Me watching..... https://t.co/rPbuBdnPKT'}
# {'id': 1517185548691161088, 'username': 'JenniferVerkui2', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -92.4367735, 'lat': 38.3045585, 'text': '@StoneColdFoxy1 On My Way 😉'}
# {'id': 1517185549332795395, 'username': 'NatLantica', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -81.7119215, 'lat': 38.819036, 'text': '@chloerose1000 @WVGOP Thank you so much! Sometimes I feel like I should give up. But kind words like yours make me feel better!!! 🙏🏼❤️🥰'}
# {'id': 1517185549827776514, 'username': 'UmeniynoraDaII', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -97.6070195, 'lat': 30.460444, 'text': 'Pink Toes x Childish Gambino'}
# {'id': 1517185549832011777, 'username': 'NWJS_jobs', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -119.82592, 'lat': 38.63288, 'text': "We're hiring! See our latest job opening: Social Services Aide-extra Help https://t.co/ZvwaFeBXG5 Markleeville, CA"}
# {'id': 1517185549617942529, 'username': 'tmj_clt_acct', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -80.8480282, 'lat': 35.2171196, 'text': 'Stop staring at the clock every day. It\'s time for a new career. Follow us to view jobs with titles like "Director… https://t.co/VRBumwKmYv'}
# {'id': 1517185550913982468, 'username': 'leandrosaeth', 'created_at': 'Thu Apr 21 16:56:37 +0000 2022', 'lng': -116.9880225, 'lat': 32.85118, 'text': '@LevelupJosh85 @ToxicSkullsClub Thank you 😍😍🚀'}
# {'id': 1517185551899795456, 'username': 'Joseph_Santoro', 'created_at': 'Thu Apr 21 16:56:38 +0000 2022', 'lng': -77.0143985, 'lat': 38.898602999999994, 'text': "They admit it. They're all unamerican enemies of the people!"}
# {'id': 1517185552176533506, 'username': 'NWJS_jobs', 'created_at': 'Thu Apr 21 16:56:38 +0000 2022', 'lng': -121.029155, 'lat': 39.202715, 'text': 'Interested in a Journeyman Auto Technician job in Grass Valley, CA? https://t.co/0N0uR13nnz This could be a great fit.'}
# {'id': 1517185553392930817, 'username': 'ThatsNoa', 'created_at': 'Thu Apr 21 16:56:38 +0000 2022', 'lng': -84.433106, 'lat': 33.7671945, 'text': 'This is good promo'}
# {'id': 1517185553371844614, 'username': 'TheOCI_NJ', 'created_at': 'Thu Apr 21 16:56:38 +0000 2022', 'lng': -74.1576, 'lat': 40.8154, 'text': 'Just posted a photo @ Nutley, New Jersey https://t.co/nUf2x2alrn'}
# {'id': 1517185554995109889, 'username': 'ThatsNoa', 'created_at': 'Thu Apr 21 16:56:38 +0000 2022', 'lng': -84.433106, 'lat': 33.7671945, 'text': 'I’m not listening but still'}
# {'id': 1517185555024560128, 'username': 'NWJS_jobs', 'created_at': 'Thu Apr 21 16:56:38 +0000 2022', 'lng': -75.116759, 'lat': 40.332324, 'text': 'Check out the latest opening https://t.co/jEkiJGdJmS at Doylestown Borough in Doylestown, PA. Constructionjobs'}
# {'id': 1517185554772742147, 'username': 'uamsnurses', 'created_at': 'Thu Apr 21 16:56:38 +0000 2022', 'lng': -92.3542193, 'lat': 34.7486563, 'text': 'At UAMS, we champion being a collaborative health care organization, focused on improving patient care and the live… https://t.co/DVdQ39LClx'}
# {'id': 1517185555238424576, 'username': 'CoastHusky', 'created_at': 'Thu Apr 21 16:56:38 +0000 2022', 'lng': -77.0143985, 'lat': 38.898602999999994, 'text': '@Mauricecherry45 Thank you ! ❤️'}
# {'id': 1517185555531911181, 'username': 'LazyDogHQ', 'created_at': 'Thu Apr 21 16:56:39 +0000 2022', 'lng': -122.0090317, 'lat': 37.3240606, 'text': 'If you have a never settle kind of attitude and like to have fun, then we want you to join our team! At Lazy Dog Re… https://t.co/xRd08D1Afk'}
# {'id': 1517185555808858113, 'username': 'jdny2', 'created_at': 'Thu Apr 21 16:56:39 +0000 2022', 'lng': -74.1873045, 'lat': 40.8085105, 'text': 'Florida might be the most corrupt place in the Western Hemisphere (and that is a high bar to clear).'}
# {'id': 1517185556232519683, 'username': 'Linux_SY', 'created_at': 'Thu Apr 21 16:56:39 +0000 2022', 'lng': -75.117998, 'lat': 40.0048655, 'text': 'Men are more attractive to beautiful women, but being attractive to beautiful heart saves you more. #JohnnyDepp'}
# {'id': 1517185556286951424, 'username': 'tonylowetweets', 'created_at': 'Thu Apr 21 16:56:39 +0000 2022', 'lng': -83.216825, 'lat': 42.54869, 'text': '@potatokinggamin @kyool_x @RokeLion @nicknprince I really shouldn’t be allowed to have Photoshop'}
# {'id': 1517185557792792576, 'username': 'NWJS_jobs', 'created_at': 'Thu Apr 21 16:56:39 +0000 2022', 'lng': -85.045718, 'lat': 41.370451, 'text': "We're hiring! See our latest job opening: Car Wash Associate https://t.co/aKuOl78sxz Auburn , IN"}
# {'id': 1517185558396690437, 'username': 'DanCevette', 'created_at': 'Thu Apr 21 16:56:39 +0000 2022', 'lng': -76.625471, 'lat': 40.296454, 'text': '@Cnmcrosby22 I guess I assumed there had to be something from the hitter.. maybe jawing.. an unprovoked pile drove… https://t.co/cKPMDBIpgx'}
# {'id': 1517185559164338176, 'username': 'RexDart1', 'created_at': 'Thu Apr 21 16:56:39 +0000 2022', 'lng': -77.349057, 'lat': 38.9558015, 'text': '@maryannjohanson @wellspokentweet Has anyone written a book like *So You Love Dinosaurs But the Last Dinosaur Book… https://t.co/k4RhChsRnh'}
# {'id': 1517185559269105664, 'username': 'Billy_Shmurda', 'created_at': 'Thu Apr 21 16:56:39 +0000 2022', 'lng': -106.0360575, 'lat': 39.505657, 'text': '#SpringBreaker! Breck doesn’t stand a chance today. #CrossCountryBill https://t.co/7rjzFBr4WJ'}
# {'id': 1517185560359624704, 'username': 'NWJS_jobs', 'created_at': 'Thu Apr 21 16:56:40 +0000 2022', 'lng': -85.306753, 'lat': 35.03167, 'text': 'Interested in a Mechanical Design Engineer job in Chattanooga, TN? https://t.co/78yPpz1ML7 This could be a great fit.'}
# {'id': 1517185561890545665, 'username': 'Mark215Oliveras', 'created_at': 'Thu Apr 21 16:56:40 +0000 2022', 'lng': -82.114383, 'lat': 41.3608395, 'text': '@JohnDBeckTV @Nickelodeon @jaydenbartels @TheMitchellBerg @GabrielleNGreen @FrankieJGrande @Scatter LET’S GO!'}
# {'id': 1517185562100305920, 'username': 'baystatespeed', 'created_at': 'Thu Apr 21 16:56:40 +0000 2022', 'lng': -71.29415900000001, 'lat': 41.939278, 'text': 'A great day indeed!'}
# {'id': 1517185562800791552, 'username': 'NWJS_jobs', 'created_at': 'Thu Apr 21 16:56:40 +0000 2022', 'lng': -81.71316, 'lat': 35.74404, 'text': 'Check out the latest opening https://t.co/Frmf1XeJ2K at Molded Fiber Glass Company in Morganton, NC. Productionjobs'}
# {'id': 1517185562762960896, 'username': 'VisualArtsTiger', 'created_at': 'Thu Apr 21 16:56:40 +0000 2022', 'lng': -95.44648649999999, 'lat': 29.838495, 'text': 'Always! 😊'}
# {'id': 1517185563325079553, 'username': 'LouManoti', 'created_at': 'Thu Apr 21 16:56:40 +0000 2022', 'lng': -89.2665075, 'lat': 39.7393005, 'text': 'I did all this shit off 16 zips'}
# the csv has been downloaded to your local computer. The program has been completed successfully.
